# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import seaborn as sns
#
# File c:\Users\joels\anaconda3\Lib\site-packages\seaborn\__init__.py:5
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
# ----> 5 from .relational import *  # noqa: F401,F403
#       6 from .regression import *  # noqa: F401,F403
#       7 from .categorical import *  # noqa: F401,F403
#
# File c:\Users\joels\anaconda3\Lib\site-packages\seaborn\relational.py:21
#      13 from .utils import (
#      14     adjust_legend_subtitles,
#      15     _default_color,
#    (...)     18     _scatter_legend_artist,
#      19 )
#      20 from ._compat import groupby_apply_include_groups
# ---> 21 from ._statistics import EstimateAggregator, WeightedAggregator
# ...

# %%
pip uninstall seaborn numpy -y
# Out:
# Found existing installation: seaborn 0.13.2
# Uninstalling seaborn-0.13.2:
#   Successfully uninstalled seaborn-0.13.2
# Found existing installation: numpy 2.3.5
# Uninstalling numpy-2.3.5:
#   Successfully uninstalled numpy-2.3.5
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\joels\AppData\Local\Temp\pip-uninstall-dfvewjdb'.
# You can safely remove it manually.

# %%
pip install numpy seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.4 MB 3.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.8/12.4 MB 3.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.1/12.4 MB 4.3 MB/s eta 0:00:03
#    ------------- -------------------------- 4.2/12.4 MB 4.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.0/12.4 MB 4.5 MB/s eta 0:00:02
#    ------------------- -------------------- 6.0/12.4 MB 4.6 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.4 MB 4.8 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.4 MB 5.0 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.4 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.4 MB 5.2 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\joels\Downloads\archive (18)\adult11.csv")
df.drop 
df.isnull
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  education-num  \
# 0   25           Private  226802          11th              7
# 1   38           Private   89814       HS-grad              9
# 2   28         Local-gov  336951    Assoc-acdm             12
# 3   44           Private  160323  Some-college             10
# 4   18                 ?  103497  Some-college             10
# 5   34           Private  198693          10th              6
# 6   29                 ?  227026       HS-grad              9
# 7   63  Self-emp-not-inc  104626   Prof-school             15
# 8   24           Private  369667  Some-college             10
# 9   55           Private  104996       7th-8th              4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        age     workclass  fnlwgt     education  education-num  \
# 0       25       Private  226802          11th              7
# 1       38       Private   89814       HS-grad              9
# 2       28     Local-gov  336951    Assoc-acdm             12
# 3       44       Private  160323  Some-college             10
# 4       18             ?  103497  Some-college             10
# ...    ...           ...     ...           ...            ...
# 48837   27       Private  257302    Assoc-acdm             12
# 48838   40       Private  154374       HS-grad              9
# 48839   58       Private  151910       HS-grad              9
# 48840   22       Private  201490       HS-grad              9
# 48841   52  Self-emp-inc  287927       HS-grad              9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.value_counts("gender")
# Out:
# gender
# Male      32650
# Female    16192
# Name: count, dtype: int64

# %%
df.value_counts("marital-status")
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
df[["race","relationship","gender","marital-status"]].value_counts()
# Out:
# race                relationship    gender  marital-status
# White               Husband         Male    Married-civ-spouse    17847
#                     Not-in-family   Male    Never-married          3493
#                     Own-child       Male    Never-married          3221
#                     Not-in-family   Female  Never-married          2573
#                     Own-child       Female  Never-married          2485
#                                                                   ...
#                     Other-relative  Female  Married-AF-spouse         1
# Other               Own-child       Male    Separated                 1
# Asian-Pac-Islander  Own-child       Male    Widowed                   1
#                     Wife            Female  Married-AF-spouse         1
# Black               Own-child       Male    Widowed                   1
# Name: count, Length: 222, dtype: int64

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  48842.000000  4.884200e+04   48842.000000  48842.000000  48842.000000
# mean      38.643585  1.896641e+05      10.078089   1079.067626     87.502314
# std       13.710510  1.056040e+05       2.570973   7452.019058    403.004552
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.175505e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.781445e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.376420e+05      12.000000      0.000000      0.000000
# max       90.000000  1.490400e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    48842.000000
# mean        40.422382
# std         12.391444
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  education-num      marital-status  \
# 0   25    Private  226802          11th              7       Never-married
# 1   38    Private   89814       HS-grad              9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm             12  Married-civ-spouse
# 3   44    Private  160323  Some-college             10  Married-civ-spouse
# 4   18          ?  103497  Some-college             10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country salary
# ...

# %%
df.shape
# Out:
# (48842, 15)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

print("All working fine")
# Out:
# All working fine

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))

sns.barplot(
    data=df,
    x="occupation",
    y="age"
)

plt.xticks(rotation=45)
plt.title("Average Age by Occupation")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting 
import parallel_coordinates

# Parallel coordinates plot
plt.figure(figsize=(12,6))
parallel_coordinates(df_encoded[["age","education-num","hours-per-week","capital-gain","capital-loss","salary"]],
                     "salary", colormap=plt.get_cmap("coolwarm"))
plt.title("Parallel Coordinates Plot of Income Dataset")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
g = sns.FacetGrid(df, col="gender", hue="salary", col_wrap=3, height=4)
g.map(sns.kdeplot, "age", fill=True)
g.add_legend()
plt.show()
# Out:
# c:\Users\joels\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   func(*plot_args, **plot_kwargs)

# %%
sns.violinplot(
    x="education",
    y="age", 
    hue="salary",
    data=df,
    split=True,
    inner="quart"
    )

plt.xticks(rotation=45)
plt.show()

# %%
import numpy as np

df_encoded = df.copy()
for col in df.select_dtypes(include="object").columns:
    df_encoded[col] = df_encoded[col].astype("category").cat.codes

corr = df_encoded.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap="coolwarm", center=0)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
sns.pairplot(
    df_encoded[["age","education-num","hours-per-week","capital-gain","capital-loss","salary"]],
             hue="salary",
             diag_kind="kde"
             )
plt.show()

# %%
sns.barplot(x="occupation", y="hours-per-week", hue="salary", data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 📊 Daily Practice: Data Cleaning and Visualization with Pandas & NumPy
#
# ## 📌 Project Overview
# This notebook demonstrates the complete workflow of data analysis using Python in VS Code Jupyter Notebook. The project focuses on importing data, cleaning the dataset, performing exploratory data analysis (EDA), and creating visualizations using Pandas, NumPy, Matplotlib, and Seaborn.
# ## 📚 Libraries Used
# - **Pandas** – Data loading, cleaning, and manipulation
# - **NumPy** – Numerical computations and array operations
# - **Matplotlib** – Basic data visualization
# - **Seaborn** – Advanced statistical visualizations
# ## 📥 Data Import
# The dataset is loaded using the Pandas library.
# **Functions Used:**
# - `pd.read_csv()"
# - `pd.read_excel()
# ## 🧹 Data Cleaning
# The dataset is cleaned to improve data quality and prepare it for analysis.
# ### Cleaning Operations
# - View first records using `head()`
# - View last records using `tail()`
# - Check dataset information using `info()`
# - Generate statistical summary using `describe()`
# - Identify missing values using `isnull()`
# - Remove missing values using `dropna()`
# - Fill missing values using `fillna()`
# - Detect duplicate records using `duplicated()`
# - Remove duplicates using `drop_duplicates()`
# - Remove unnecessary columns using `drop()`
# - Rename columns where required
# - Check data types using `dtypes`
# ## 📈 Data Visualization
# Visualizations are created using Matplotlib and Seaborn to better understand patterns and trends within the dataset.
# ### Charts Used
# - 📊 Bar Chart
# - 📈 Line Chart
# - 🥧 Pie Chart
# - 📉 Histogram
# - 📦 Box Plot
# - 🔥 Heatmap
# - 🎯 Scatter Plot
# - 🌸 Pair Plot
# - 🎻 Violin Plot
# ## 🎯 Objectives
#
# - Practice data cleaning techniques using Pandas.
# - Explore datasets through Exploratory Data Analysis (EDA).
# - Build meaningful visualizations using Matplotlib and Seaborn.
# - Improve Python programming skills in VS Code Jupyter Notebook.
# - Understand relationships, distributions, trends, and correlations in data.
# ## 🛠️ Technologies Used
# - Python
# - VS Code
# - Jupyter Notebook
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# ## 🚀 Learning Outcome
# This notebook demonstrates a complete data analysis workflow, including data importing, cleaning, preprocessing, exploratory data analysis, and visualization. It serves as a daily practice project to strengthen Python, Pandas, NumPy, Matplotlib, and Seaborn skills for data analytics and data science.
